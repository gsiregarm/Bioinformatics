# %% [markdown]
# <a href="https://colab.research.google.com/github/gsiregarm/Bioinformatics/blob/main/DeeplearningProteinStructure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# === STEP 1: Baca CSV dari Google Drive ===
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/Colab_Notebooks/dataset_sec_protein.csv')

#df = dataframe protein

# === STEP 2: Pra-pemrosesan Data ===
X = df.drop(columns=['Class']).values
y = LabelEncoder().fit_transform(df['Class'])

# Normalisasi fitur
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Ubah ke tensor (tensor adalah representasi data agar dapat mudah diakses GPU)
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.long)

# === STEP 3: Melakukan Definisi Model DNN (3 hidden layers) ===
class DNN(nn.Module):
 def __init__(self, input_size, hidden_size, num_classes):
  super(DNN, self).__init__()
  self.model = nn.Sequential(
  nn.Linear(input_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, num_classes)
 )
 def forward(self, x):
  return self.model(x)

# === STEP 4: Cross Validation ===
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
accuracies = []

for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
 print(f"\nFold {fold+1}")
 X_train, X_test = X[train_idx], X[test_idx]
 y_train, y_test = y[train_idx], y[test_idx]
 model = DNN(input_size=261, hidden_size=16, num_classes=3)
 criterion = nn.CrossEntropyLoss()
 optimizer = optim.Adam(model.parameters(), lr=0.01)

 # Training
 for epoch in range(100):
  model.train()
 outputs = model(X_train)
 loss = criterion(outputs, y_train)
 optimizer.zero_grad()
 loss.backward()
 optimizer.step()

 # Evaluasi
 model.eval()
 with torch.no_grad():
  outputs = model(X_test)
 _, predicted = torch.max(outputs.data, 1)
 acc = accuracy_score(y_test.numpy(), predicted.numpy())
 print(f"Akurasi Fold {fold+1}: {acc:.4f}")
 accuracies.append(acc)

 # === STEP 5: Rata-rata Akurasi ===
print(f"\nRata-rata Akurasi Cross Validation: {np.mean(accuracies):.4f}")
# Out:
# Mounted at /content/drive
#
# Fold 1
# Akurasi Fold 1: 0.5600
#
# Fold 2
# Akurasi Fold 2: 0.6400
#
# Fold 3
# Akurasi Fold 3: 0.5667
#
# Fold 4
# Akurasi Fold 4: 0.4867
#
# Fold 5
# Akurasi Fold 5: 0.1667
#
# Fold 6
# Akurasi Fold 6: 0.5600
#
# Fold 7
# Akurasi Fold 7: 0.5533
#
# Fold 8
# Akurasi Fold 8: 0.2733
#
# Fold 9
# Akurasi Fold 9: 0.4400
#
# Fold 10
# Akurasi Fold 10: 0.5638
#
# Rata-rata Akurasi Cross Validation: 0.4810

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# === STEP 1: Baca CSV dari Google Drive ===
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/Colab_Notebooks/dataset_sec_protein.csv')

#df = dataframe protein

# === STEP 2: Pra-pemrosesan Data ===
X = df.drop(columns=['Class']).values
y = LabelEncoder().fit_transform(df['Class'])

# Normalisasi fitur
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Ubah ke tensor (tensor adalah representasi data agar dapat mudah diakses GPU)
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.long)

# === STEP 3: Melakukan Definisi Model DNN (6 hidden layers) ===
class DNN(nn.Module):
 def __init__(self, input_size, hidden_size, num_classes):
  super(DNN, self).__init__()
  self.model = nn.Sequential(
  nn.Linear(input_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, num_classes)
 )
 def forward(self, x):
  return self.model(x)

# === STEP 4: Cross Validation ===
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
accuracies = []

for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
 print(f"\nFold {fold+1}")
 X_train, X_test = X[train_idx], X[test_idx]
 y_train, y_test = y[train_idx], y[test_idx]
 model = DNN(input_size=261, hidden_size=64, num_classes=6)
 criterion = nn.CrossEntropyLoss()
 optimizer = optim.Adam(model.parameters(), lr=0.01)

 # Training
 for epoch in range(100):
  model.train()
 outputs = model(X_train)
 loss = criterion(outputs, y_train)
 optimizer.zero_grad()
 loss.backward()
 optimizer.step()

 # Evaluasi
 model.eval()
 with torch.no_grad():
  outputs = model(X_test)
 _, predicted = torch.max(outputs.data, 1)
 acc = accuracy_score(y_test.numpy(), predicted.numpy())
 print(f"Akurasi Fold {fold+1}: {acc:.4f}")
 accuracies.append(acc)

 # === STEP 5: Rata-rata Akurasi ===
print(f"\nRata-rata Akurasi Cross Validation: {np.mean(accuracies):.4f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Fold 1
# Akurasi Fold 1: 0.6267
#
# Fold 2
# Akurasi Fold 2: 0.5600
#
# Fold 3
# Akurasi Fold 3: 0.5800
#
# Fold 4
# Akurasi Fold 4: 0.5600
#
# Fold 5
# Akurasi Fold 5: 0.5133
#
# Fold 6
# Akurasi Fold 6: 0.5800
#
# Fold 7
# Akurasi Fold 7: 0.5600
#
# Fold 8
# Akurasi Fold 8: 0.5067
#
# Fold 9
# Akurasi Fold 9: 0.5867
#
# Fold 10
# Akurasi Fold 10: 0.2752
#
# Rata-rata Akurasi Cross Validation: 0.5349

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# === STEP 1: Baca CSV dari Google Drive ===
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/Colab_Notebooks/dataset_sec_protein.csv')

#df = dataframe protein

# === STEP 2: Pra-pemrosesan Data ===
X = df.drop(columns=['Class']).values
y = LabelEncoder().fit_transform(df['Class'])

# Normalisasi fitur
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Ubah ke tensor (tensor adalah representasi data agar dapat mudah diakses GPU)
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.long)

# === STEP 3: Melakukan Definisi Model DNN (3 hidden layers) ditambah dropout rate ===
class DNN(nn.Module):
 def __init__(self, input_size, hidden_size, num_classes,dropout_rate=0.2):
  super(DNN, self).__init__()
  self.model = nn.Sequential(
  nn.Linear(input_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, hidden_size),
  nn.ReLU(),
  nn.Linear(hidden_size, hidden_size),
  nn.ReLU(),
  nn.Dropout(dropout_rate),
  nn.Linear(hidden_size, num_classes)
 )
 def forward(self, x):
  return self.model(x)

# === STEP 4: Cross Validation ===
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
accuracies = []

batch_size = 32

#Iterasi baru menggunakan batch size
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
 print(f"\nFold {fold+1}")
 X_train, X_test = X[train_idx], X[test_idx]
 y_train, y_test = y[train_idx], y[test_idx]
 train_dataset = TensorDataset(X_train, y_train)
 train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

 model = DNN(input_size=261, hidden_size=64, num_classes=6)
 criterion = nn.CrossEntropyLoss()
 optimizer = optim.Adam(model.parameters(), lr=0.01)

 # Training
 for epoch in range(100):
  model.train()
  for batch_X, batch_y in train_loader:
    outputs = model(batch_X)
    loss = criterion(outputs, batch_y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

 # Evaluasi
 model.eval()
 with torch.no_grad():
  outputs = model(X_test)
 _, predicted = torch.max(outputs.data, 1)
 acc = accuracy_score(y_test.numpy(), predicted.numpy())
 print(f"Akurasi Fold {fold+1}: {acc:.4f}")
 accuracies.append(acc)

 # === STEP 5: Rata-rata Akurasi ===
print(f"\nRata-rata Akurasi Cross Validation: {np.mean(accuracies):.4f}")
# Out:
# Mounted at /content/drive
#
# Fold 1
# Akurasi Fold 1: 0.7667
#
# Fold 2
# Akurasi Fold 2: 0.7733
#
# Fold 3
# Akurasi Fold 3: 0.7400
#
# Fold 4
# Akurasi Fold 4: 0.8000
#
# Fold 5
# Akurasi Fold 5: 0.8267
#
# Fold 6
# Akurasi Fold 6: 0.7867
#
# Fold 7
# Akurasi Fold 7: 0.7867
#
# Fold 8
# Akurasi Fold 8: 0.7867
#
# Fold 9
# Akurasi Fold 9: 0.8133
#
# Fold 10
# Akurasi Fold 10: 0.7584
#
# Rata-rata Akurasi Cross Validation: 0.7838
